# %%
from typing import Tuple, List, Union, Any, Optional, Dict, Literal, Callable, Type
import pathlib
from pathlib import Path
import pickle as pkl

from tqdm import tqdm
import numpy as np
import torch
import torch.nn as nn
import torch.optim
import torch.utils.data
from torch import Tensor
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.image as mpimg
from matplotlib.colors import ListedColormap
from sklearn.model_selection import GridSearchCV

from models.base import FittableModule, LogisticRegression
from models.end2end import End2EndMLPResNet
from models.random_feature_representation_boosting import GradientRFRBoostClassifier
from models.gridsearch_wrapper import SKLearnWrapper

# %%
class Config:
    save_dir = Path.cwd() / "results" / "ConcentricCircles"

# %%
#######################################################
##### Create Synthetic Concentric Circles Dataset #####
#######################################################


def acc_from_logits(logits, y, n_classes):
    if n_classes==2:
        pred = (logits>0).float()
    else:
        pred = torch.argmax(logits, dim=1)
        y = torch.argmax(y, dim=1)
    acc = (pred==y).float().mean()
    return acc


def generate_concentric_rings(n_rings_per_class=2, n_classes=3, n_samples=2000, device="cpu", plot=False) -> Tuple[np.ndarray, np.ndarray]:
    X = []
    y = []
    n_rings = n_rings_per_class * n_classes
    samples_per_ring = n_samples // n_rings
    for i in range(n_rings):
        radius = i + 1
        theta = np.linspace(0, 2 * np.pi, samples_per_ring)
        noise_scale = 0.4
        x1 = radius * np.cos(theta) + np.random.rand(samples_per_ring) * noise_scale
        x2 = radius * np.sin(theta) + np.random.rand(samples_per_ring) * noise_scale
        X.append(np.vstack((x1, x2)).T)
        y.append(np.full(samples_per_ring, i % n_classes))
    X = np.vstack(X)
    y = np.hstack(y)
    perm = np.random.permutation(len(X))
    X = X[perm] / np.max(X)
    y = y[perm]

    #plot
    if plot:
        plt.figure(figsize=(8, 8))
        for i in range(n_classes):
            plt.scatter(X[y == i][:, 0], X[y == i][:, 1], label=f'Class {i}')
        plt.legend()
        plt.title('Concentric Rings Dataset')
        plt.xlabel('x1')
        plt.ylabel('x2')
        plt.show()

    y = torch.tensor(y).float()
    X = torch.tensor(X).float()
    if n_classes > 2:
        y = torch.nn.functional.one_hot(y.to(torch.int64), n_classes).float()
    else:
        y = y.unsqueeze(1)

    r = int(0.5 * len(X))
    X_train, y_train, X_test, y_test = X[:r], y[:r], X[r:], y[r:]
    return (X_train.to(device),
            y_train.to(device), 
            X_test.to(device), 
            y_test.to(device) )


np.random.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed(0)
n_classes = 3
D = 2
device = "cpu"
X_train, y_train, X_test, y_test = generate_concentric_rings(
    n_rings_per_class=3, n_classes=n_classes, n_samples=6000, device=device
    )
if n_classes > 2:
    loss_fn = nn.functional.cross_entropy
else:
    loss_fn = nn.functional.binary_cross_entropy_with_logits

# %% [markdown]
# # How do i want to set up the experiments?

# %%
import json

def save_feature_plot(
        X_train, 
        y_train, 
        X_test, 
        y_test, 
        model, 
        n_classes, 
        file_name: str,
        ):
    """
    Saves train and test features side by side for visualization at a given layer.
    
    Args:
        X_train (torch.Tensor): Features of the training set (shape: [n_samples, 2]).
        y_train (torch.Tensor): Labels of the training set (one-hot or integer-encoded).
        X_test (torch.Tensor): Features of the test set (shape: [n_samples, 2]).
        y_test (torch.Tensor): Labels of the test set (one-hot or integer-encoded).
        n_classes (int): Number of classes in the dataset.
        file_name (str): Name of the file to save the plot.
    """
    # Obtain the features at each layer
    train_features = [X_train]
    test_features = [X_test]
    if type(model) == GradientRFRBoostClassifier:
        X0_train = X_train
        X0_test = X_test
        for t, (feat_layer, ghat_layer, batchnorm) in enumerate(zip(model.random_feature_layers, 
                                                                     model.ghat_boosting_layers, 
                                                                     model.batchnorms)):
            model.train()
            features_train = feat_layer(X_train, X0_train)
            X_train = X_train + model.boost_lr * ghat_layer(features_train)
            X_train = batchnorm(X_train)
            model.eval()
            features_test = feat_layer(X_test, X0_test)
            X_test = X_test + model.boost_lr * ghat_layer(features_test)
            X_test = batchnorm(X_test)
            train_features.append(X_train)
            test_features.append(X_test)
    elif type(model) == End2EndMLPResNet:
        for resblock in model.residual_blocks:
            model.train()
            X_train = X_train + resblock(X_train)
            model.eval()
            X_test = X_test + resblock(X_test)
            train_features.append(X_train)
            test_features.append(X_test)
    else:
        raise ValueError("Model type not recognized.")
    
    # Convert labels to integers if they're one-hot encoded
    train_labels_np = y_train.argmax(dim=1).cpu().numpy() if n_classes > 2 else y_train.cpu().numpy()
    test_labels_np = y_test.argmax(dim=1).cpu().numpy() if n_classes > 1 else y_test.cpu().numpy()

    # Plot the features
    fontsize=30
    name = "E2E MLP ResNet" if type(model) == End2EndMLPResNet else "RFRBoost"
    custom_cmap = ListedColormap(['#ff7f0e', '#2ca02c', '#1f77b4'])  # Orange, Green, Blue
    T = len(train_features)
    for name_train_or_test, features, labels in [("train", train_features, train_labels_np), 
                                                 ("test", test_features, test_labels_np)]:
        fig, axes = plt.subplots(1, T, figsize=(T * 4, 4), dpi=100)
        for t in range(T):
            ax = axes[t]
            feat = features[t].detach().cpu().numpy()

            ax.scatter(feat[:, 0], feat[:, 1], c=labels, cmap=custom_cmap, s=40, alpha=0.5, edgecolors='none')

            # Remove titles and adjust axis
            ax.axis('equal')
            ax.axis('off')

            # Add black border as a rectangle
            rect = patches.Rectangle(
                (0, 0), 1, 1, transform=ax.transAxes,  # Set size relative to axes
                linewidth=2, edgecolor='black', facecolor='none', zorder=10
            )
            ax.add_patch(rect)

        # Add vertical label for the model name
        fig.text(0.015, 0.5, name, fontsize=fontsize, rotation='vertical', va='center', ha='center')

        plt.tight_layout()
        plt.subplots_adjust(left=0.03)  # Add space for the model name
        plt.savefig(Config.save_dir / f"{file_name}_{name_train_or_test}.png", bbox_inches='tight', dpi=300)
        # plt.savefig(Config.save_dir / f"{file_name}_{name_train_or_test}.eps", bbox_inches='tight')
        plt.close(fig)



def run_concentric_rings_experiment(
        seed=0,
        k_folds=5,
        n_classes=3,
        n_rings_per_class=3,
        n_samples=10000,
        device="cpu",
        ):
    """Runs the concentric circle experiments and saves the plots and results."""
    # Define models and their hyperparameter grids
    n_layers = 3
    bottleneck_dim = 512
    model_specs = {
        "RFRBoost SWIM": {
            'modelClass': [GradientRFRBoostClassifier],
            'l2_cls': np.logspace(-4, 0, 5),
            'l2_ghat': [1e-5],
            'in_dim': [2],
            'n_classes': [n_classes],
            'hidden_dim': [2],
            'n_layers': [n_layers],
            'randfeat_xt_dim': [bottleneck_dim],
            'randfeat_x0_dim': [bottleneck_dim],
            'upscale_type': ["identity"],
            'feature_type': ["SWIM"],
            'SWIM_scale': [1.0],
            'activation': ["tanh"],
            "use_batchnorm": [True],
            "boost_lr": [0.1],
        },
        "RFNN": {
            'modelClass': [GradientRFRBoostClassifier],
            'l2_cls': np.logspace(-4, 0, 5),
            'in_dim': [2],
            'n_classes': [n_classes],
            'hidden_dim': [512],
            'n_layers': [0],
            'upscale_type': ["SWIM"],
            'SWIM_scale': [1.0],
            'activation': ["tanh"],
        },
        "Logistic Regression": {
            'modelClass': [LogisticRegression],
            'l2_lambda': np.logspace(-4, 0, 5),
            'n_classes': [n_classes],
        },
        "End2EndMLP": {
            'modelClass': [End2EndMLPResNet],
            'lr': np.logspace(-6, -2, 5),
            'in_dim': [2],
            'hidden_dim': [2],
            'bottleneck_dim': [bottleneck_dim],
            'out_dim': [n_classes if n_classes > 2 else 1],
            'n_blocks': [n_layers],
            'loss': ["cce" if n_classes > 2 else "bce"],
            'n_epochs': [30],
            'end_lr_factor': [0.01],
            'weight_decay': [0.00001],
            'batch_size': [64],
            'upsample': [False],
            'activation': [nn.Tanh()],
        },
    }

    # Run experiments
    results = {}
    results_params = {}
    for model_name, param_grid in model_specs.items():
        accuracies = []
        best_params = []
        for i in range(10):
            # Set seed
            np.random.seed(seed+i)
            torch.manual_seed(seed+i)
            torch.cuda.manual_seed(seed+i)

            # Create dataset
            X_train, y_train, X_test, y_test = generate_concentric_rings(
                n_rings_per_class, n_classes, n_samples, device
            )

            # Perform grid search with k-fold cross-validation
            estimator = SKLearnWrapper()
            grid_search = GridSearchCV(
                estimator=estimator,
                param_grid= {**param_grid, **{"seed": [seed+i]}},
                cv=5,
            )
            grid_search.fit(X_train, y_train)
            best_model = grid_search.best_estimator_
            best_model.set_model_eval()
            accuracy = best_model.score(X_test, y_test)
            accuracies.append(accuracy)
            best_params.append(grid_search.best_params_)

            print(i, model_name, "test acc", accuracy, "params", grid_search.best_params_)

            if i == 0 and ("RFRBoost" in model_name or "MLP" in model_name):
                print("plotting and saving feature evolution point cloud")
                save_feature_plot(X_train, y_train, X_test, y_test, best_model.model, n_classes, model_name)
        results[model_name] = accuracies
        results_params[model_name] = best_params

    # Save results to a file
    with open(Config.save_dir / f"combined_results.pkl", "wb") as f:
        pkl.dump(results, f)

    return results, results_params

results, results_params = run_concentric_rings_experiment()

for model_name, accs in results.items():
    print(model_name, "acc", np.mean(accs), "std", np.std(accs))
    print(accs)
    print()
for model_name, best_params in results_params.items():
    print(model_name, "best params", best_params)
    print()
# Out:
# 0 RFRBoost SWIM test acc 0.9980000257492065 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 0, 'upscale_type': 'identity', 'use_batchnorm': True}
# plotting and saving feature evolution point cloud
# 1 RFRBoost SWIM test acc 0.9976000189781189 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 1, 'upscale_type': 'identity', 'use_batchnorm': True}
# 2 RFRBoost SWIM test acc 0.9977999925613403 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 2, 'upscale_type': 'identity', 'use_batchnorm': True}
# 3 RFRBoost SWIM test acc 0.9908000230789185 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 3, 'upscale_type': 'identity', 'use_batchnorm': True}
# 4 RFRBoost SWIM test acc 0.9986000061035156 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.01, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 4, 'upscale_type': 'identity', 'use_batchnorm': True}
# 5 RFRBoost SWIM test acc 0.9987999796867371 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 5, 'upscale_type': 'identity', 'use_batchnorm': True}
# 6 RFRBoost SWIM test acc 0.9950000047683716 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 6, 'upscale_type': 'identity', 'use_batchnorm': True}
# 7 RFRBoost SWIM test acc 0.9990000128746033 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 7, 'upscale_type': 'identity', 'use_batchnorm': True}
# 8 RFRBoost SWIM test acc 0.9958000183105469 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 8, 'upscale_type': 'identity', 'use_batchnorm': True}
# 9 RFRBoost SWIM test acc 0.9986000061035156 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 9, 'upscale_type': 'identity', 'use_batchnorm': True}
# 0 RFNN test acc 0.8873999714851379 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 0, 'upscale_type': 'SWIM'}
# 1 RFNN test acc 0.8622000217437744 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 1, 'upscale_type': 'SWIM'}
# 2 RFNN test acc 0.9128000140190125 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 2, 'upscale_type': 'SWIM'}
# 3 RFNN test acc 0.852400004863739 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 3, 'upscale_type': 'SWIM'}
# 4 RFNN test acc 0.9168000221252441 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 4, 'upscale_type': 'SWIM'}
# 5 RFNN test acc 0.8628000020980835 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 5, 'upscale_type': 'SWIM'}
# 6 RFNN test acc 0.876800000667572 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 6, 'upscale_type': 'SWIM'}
# 7 RFNN test acc 0.8781999945640564 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 7, 'upscale_type': 'SWIM'}
# 8 RFNN test acc 0.8253999948501587 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 8, 'upscale_type': 'SWIM'}
# 9 RFNN test acc 0.9065999984741211 params {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 9, 'upscale_type': 'SWIM'}
# 0 Logistic Regression test acc 0.33160001039505005 params {'l2_lambda': 1.0, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 0}
# 1 Logistic Regression test acc 0.2863999903202057 params {'l2_lambda': 0.01, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 1}
# 2 Logistic Regression test acc 0.35120001435279846 params {'l2_lambda': 0.0001, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 2}
# 3 Logistic Regression test acc 0.32919999957084656 params {'l2_lambda': 1.0, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 3}
# 4 Logistic Regression test acc 0.33399999141693115 params {'l2_lambda': 0.01, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 4}
# 5 Logistic Regression test acc 0.32499998807907104 params {'l2_lambda': 0.01, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 5}
# 6 Logistic Regression test acc 0.328000009059906 params {'l2_lambda': 0.1, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 6}
# 7 Logistic Regression test acc 0.3555999994277954 params {'l2_lambda': 0.0001, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 7}
# 8 Logistic Regression test acc 0.32420000433921814 params {'l2_lambda': 1.0, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 8}
# 9 Logistic Regression test acc 0.3070000112056732 params {'l2_lambda': 0.01, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 9}
# 100%|██████████| 30/30 [00:09<00:00,  3.12it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.22it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.35it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.55it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.67it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.70it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.71it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.72it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.46it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.39it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.52it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.38it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.27it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.59it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.99it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.50it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.57it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.22it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.84it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.46it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.31it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.82it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.89it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.96it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.97it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.16it/s]
# 0 End2EndMLP test acc 0.5425999760627747 params {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 0, 'upsample': False, 'weight_decay': 1e-05}
# plotting and saving feature evolution point cloud
# 100%|██████████| 30/30 [00:08<00:00,  3.71it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.54it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.40it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.46it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.90it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.64it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.39it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.53it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.70it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.01it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.08it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.17it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.88it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.51it/s]
# 100%|██████████| 30/30 [00:10<00:00,  2.98it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.60it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.55it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.60it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.43it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.40it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.51it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.75it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.38it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.89it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.99it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.18it/s]
# 1 End2EndMLP test acc 0.3508000075817108 params {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.0001, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 1, 'upsample': False, 'weight_decay': 1e-05}
# 100%|██████████| 30/30 [00:07<00:00,  4.02it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.80it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.49it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.90it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.96it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.91it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.80it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.93it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.92it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.10it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.87it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.70it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.83it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.60it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.63it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.90it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.80it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.83it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.70it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.78it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.51it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.32it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.55it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.48it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.72it/s]
# 100%|██████████| 30/30 [00:10<00:00,  2.90it/s]
# 2 End2EndMLP test acc 0.5968000292778015 params {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 2, 'upsample': False, 'weight_decay': 1e-05}
# 100%|██████████| 30/30 [00:08<00:00,  3.74it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.79it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.80it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.69it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.81it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.76it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.84it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.78it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.76it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.76it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.80it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.65it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.82it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.18it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.19it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.57it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.82it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.82it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.78it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.82it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.81it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.72it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.46it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.65it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.83it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.04it/s]
# 3 End2EndMLP test acc 0.4083999991416931 params {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 3, 'upsample': False, 'weight_decay': 1e-05}
# 100%|██████████| 30/30 [00:08<00:00,  3.70it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.11it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.41it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.51it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.78it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.64it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.81it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.71it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.82it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.62it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.30it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.58it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.22it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.34it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.78it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.60it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.84it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.76it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.72it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.71it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.42it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.67it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.66it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.82it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.64it/s]
# 100%|██████████| 30/30 [00:10<00:00,  2.92it/s]
# 4 End2EndMLP test acc 0.4156000018119812 params {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 4, 'upsample': False, 'weight_decay': 1e-05}
# 100%|██████████| 30/30 [00:09<00:00,  3.32it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.72it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.55it/s]
# 100%|██████████| 30/30 [00:10<00:00,  2.95it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.37it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.65it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.61it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.81it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.50it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.56it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.73it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.48it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.52it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.47it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.49it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.79it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.46it/s]
# 100%|██████████| 30/30 [00:10<00:00,  2.96it/s]
# 100%|██████████| 30/30 [00:10<00:00,  2.83it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.08it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.32it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.30it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.18it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.20it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.11it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.60it/s]
# 5 End2EndMLP test acc 0.4075999855995178 params {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 5, 'upsample': False, 'weight_decay': 1e-05}
# 100%|██████████| 30/30 [00:08<00:00,  3.35it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.21it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.24it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.40it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.31it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.06it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.70it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.85it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.78it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.94it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.84it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.94it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.86it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.86it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.88it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.87it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.85it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.89it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.87it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.96it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.84it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.93it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.85it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.89it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.83it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.09it/s]
# 6 End2EndMLP test acc 0.5655999779701233 params {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 6, 'upsample': False, 'weight_decay': 1e-05}
# 100%|██████████| 30/30 [00:07<00:00,  3.91it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.94it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.93it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.91it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.83it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.75it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.82it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.89it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.86it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.92it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.88it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.93it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.76it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.90it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.93it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.93it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.89it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.83it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.76it/s]
# 100%|██████████| 30/30 [00:07<00:00,  3.89it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.17it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.16it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.25it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.21it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.23it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.34it/s]
# 7 End2EndMLP test acc 0.38519999384880066 params {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.001, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 7, 'upsample': False, 'weight_decay': 1e-05}
# 100%|██████████| 30/30 [00:07<00:00,  4.26it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.19it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.24it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.18it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.21it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.20it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.24it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.20it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.23it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.22it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.25it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.18it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.22it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.13it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.19it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.24it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.22it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.22it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.19it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.05it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.17it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.21it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.17it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.21it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.16it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.36it/s]
# 8 End2EndMLP test acc 0.41819998621940613 params {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.0001, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 8, 'upsample': False, 'weight_decay': 1e-05}
# 100%|██████████| 30/30 [00:07<00:00,  4.20it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.23it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.19it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.61it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.65it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.43it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.24it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.16it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.06it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.19it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.11it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.20it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.30it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.03it/s]
# 100%|██████████| 30/30 [00:10<00:00,  2.99it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.08it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.62it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.62it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.50it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.64it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.58it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.70it/s]
# 100%|██████████| 30/30 [00:08<00:00,  3.59it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.71it/s]
# 100%|██████████| 30/30 [00:10<00:00,  2.93it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.56it/s]
# 9 End2EndMLP test acc 0.79339998960495 params {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 9, 'upsample': False, 'weight_decay': 1e-05}
# RFRBoost SWIM acc 0.9970000088214874 std 0.002413290919220536
# [0.9980000257492065, 0.9976000189781189, 0.9977999925613403, 0.9908000230789185, 0.9986000061035156, 0.9987999796867371, 0.9950000047683716, 0.9990000128746033, 0.9958000183105469, 0.9986000061035156]
#
# RFNN acc 0.87814000248909 std 0.027435170129586194
# [0.8873999714851379, 0.8622000217437744, 0.9128000140190125, 0.852400004863739, 0.9168000221252441, 0.8628000020980835, 0.876800000667572, 0.8781999945640564, 0.8253999948501587, 0.9065999984741211]
#
# Logistic Regression acc 0.3272200018167496 std 0.018813072600752805
# [0.33160001039505005, 0.2863999903202057, 0.35120001435279846, 0.32919999957084656, 0.33399999141693115, 0.32499998807907104, 0.328000009059906, 0.3555999994277954, 0.32420000433921814, 0.3070000112056732]
#
# End2EndMLP acc 0.4884199947118759 std 0.1290013772526847
# [0.5425999760627747, 0.3508000075817108, 0.5968000292778015, 0.4083999991416931, 0.4156000018119812, 0.4075999855995178, 0.5655999779701233, 0.38519999384880066, 0.41819998621940613, 0.79339998960495]
#
# RFRBoost SWIM best params [{'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 0, 'upscale_type': 'identity', 'use_batchnorm': True}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 1, 'upscale_type': 'identity', 'use_batchnorm': True}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 2, 'upscale_type': 'identity', 'use_batchnorm': True}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 3, 'upscale_type': 'identity', 'use_batchnorm': True}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.01, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 4, 'upscale_type': 'identity', 'use_batchnorm': True}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 5, 'upscale_type': 'identity', 'use_batchnorm': True}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 6, 'upscale_type': 'identity', 'use_batchnorm': True}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 7, 'upscale_type': 'identity', 'use_batchnorm': True}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 8, 'upscale_type': 'identity', 'use_batchnorm': True}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 9, 'upscale_type': 'identity', 'use_batchnorm': True}]
#
# RFNN best params [{'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 0, 'upscale_type': 'SWIM'}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 1, 'upscale_type': 'SWIM'}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 2, 'upscale_type': 'SWIM'}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 3, 'upscale_type': 'SWIM'}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 4, 'upscale_type': 'SWIM'}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 5, 'upscale_type': 'SWIM'}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 6, 'upscale_type': 'SWIM'}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 7, 'upscale_type': 'SWIM'}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 8, 'upscale_type': 'SWIM'}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 9, 'upscale_type': 'SWIM'}]
#
# Logistic Regression best params [{'l2_lambda': 1.0, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 0}, {'l2_lambda': 0.01, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 1}, {'l2_lambda': 0.0001, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 2}, {'l2_lambda': 1.0, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 3}, {'l2_lambda': 0.01, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 4}, {'l2_lambda': 0.01, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 5}, {'l2_lambda': 0.1, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 6}, {'l2_lambda': 0.0001, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 7}, {'l2_lambda': 1.0, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 8}, {'l2_lambda': 0.01, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 9}]
#
# End2EndMLP best params [{'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 0, 'upsample': False, 'weight_decay': 1e-05}, {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.0001, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 1, 'upsample': False, 'weight_decay': 1e-05}, {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 2, 'upsample': False, 'weight_decay': 1e-05}, {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 3, 'upsample': False, 'weight_decay': 1e-05}, {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 4, 'upsample': False, 'weight_decay': 1e-05}, {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 5, 'upsample': False, 'weight_decay': 1e-05}, {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 6, 'upsample': False, 'weight_decay': 1e-05}, {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.001, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 7, 'upsample': False, 'weight_decay': 1e-05}, {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.0001, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 8, 'upsample': False, 'weight_decay': 1e-05}, {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 9, 'upsample': False, 'weight_decay': 1e-05}]

# %%
with open(Config.save_dir / "combined_results.pkl", "rb") as f:
    results = pkl.load(f)

# %%
results
# Out:
# {'RFRBoost SWIM': [0.9980000257492065,
#   0.9976000189781189,
#   0.9977999925613403,
#   0.9908000230789185,
#   0.9986000061035156,
#   0.9987999796867371,
#   0.9950000047683716,
#   0.9990000128746033,
#   0.9958000183105469,
#   0.9986000061035156],
#  'RFNN': [0.8873999714851379,
#   0.8622000217437744,
#   0.9128000140190125,
#   0.852400004863739,
#   0.9168000221252441,
#   0.8628000020980835,
#   0.876800000667572,
#   0.8781999945640564,
#   0.8253999948501587,
#   0.9065999984741211],
#  'Logistic Regression': [0.33160001039505005,
#   0.2863999903202057,
#   0.35120001435279846,
#   0.32919999957084656,
#   0.33399999141693115,
#   0.32499998807907104,
#   0.328000009059906,
#   0.3555999994277954,
#   0.32420000433921814,
#   0.3070000112056732],
#  'End2EndMLP': [0.5425999760627747,
#   0.3508000075817108,
#   0.5968000292778015,
#   0.4083999991416931,
#   0.4156000018119812,
#   0.4075999855995178,
#   0.5655999779701233,
#   0.38519999384880066,
#   0.41819998621940613,
#   0.79339998960495]}

# %%
def make_combined_plot():
    # List of image paths
    plots = [
        "results/ConcentricCircles/RFRBoost SWIM_test.png",
        "results/ConcentricCircles/End2EndMLP_test.png"
    ]

    # Create a figure to hold the subplots
    fig, axes = plt.subplots(len(plots), 1, figsize=(30, 15))

    # Loop through the images and add them to the subplots
    for ax, plot in zip(axes, plots):
        img = mpimg.imread(plot)
        ax.imshow(img)
        ax.axis('off')  # Hide the axes

    # Add text below the subplots
    left_indent = 0.225
    height = 0.08
    fig.text(left_indent, height, 'input', ha='center', fontsize=45)
    for t in range(1, 3+1):
        fig.text(left_indent + t/4*0.77, height, f't={t}', ha='center', fontsize=45)
    # Adjust layout to avoid overlap and reduce vertical space
    plt.subplots_adjust(left=0.01, right=0.99, hspace=0.0001)
    plt.savefig("results/ConcentricCircles/ConcentricEvolution.png", bbox_inches='tight')
    plt.show()
    plt.close()

make_combined_plot()

# %%
for model_name, accs in results.items():
    print(model_name, "acc", np.mean(accs), "std", np.std(accs))
    print(accs)
    print()
for model_name, best_params in results_params.items():
    print(model_name, "best params", best_params)
    print()
# Out:
# RFRBoost SWIM acc 0.9970000088214874 std 0.002413290919220536
# [0.9980000257492065, 0.9976000189781189, 0.9977999925613403, 0.9908000230789185, 0.9986000061035156, 0.9987999796867371, 0.9950000047683716, 0.9990000128746033, 0.9958000183105469, 0.9986000061035156]
#
# RFNN acc 0.87814000248909 std 0.027435170129586194
# [0.8873999714851379, 0.8622000217437744, 0.9128000140190125, 0.852400004863739, 0.9168000221252441, 0.8628000020980835, 0.876800000667572, 0.8781999945640564, 0.8253999948501587, 0.9065999984741211]
#
# Logistic Regression acc 0.3272200018167496 std 0.018813072600752805
# [0.33160001039505005, 0.2863999903202057, 0.35120001435279846, 0.32919999957084656, 0.33399999141693115, 0.32499998807907104, 0.328000009059906, 0.3555999994277954, 0.32420000433921814, 0.3070000112056732]
#
# End2EndMLP acc 0.4884199947118759 std 0.1290013772526847
# [0.5425999760627747, 0.3508000075817108, 0.5968000292778015, 0.4083999991416931, 0.4156000018119812, 0.4075999855995178, 0.5655999779701233, 0.38519999384880066, 0.41819998621940613, 0.79339998960495]
#
# RFRBoost SWIM best params [{'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 0, 'upscale_type': 'identity', 'use_batchnorm': True}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 1, 'upscale_type': 'identity', 'use_batchnorm': True}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 2, 'upscale_type': 'identity', 'use_batchnorm': True}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 3, 'upscale_type': 'identity', 'use_batchnorm': True}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.01, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 4, 'upscale_type': 'identity', 'use_batchnorm': True}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 5, 'upscale_type': 'identity', 'use_batchnorm': True}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 6, 'upscale_type': 'identity', 'use_batchnorm': True}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 7, 'upscale_type': 'identity', 'use_batchnorm': True}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 8, 'upscale_type': 'identity', 'use_batchnorm': True}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'boost_lr': 0.1, 'feature_type': 'SWIM', 'hidden_dim': 2, 'in_dim': 2, 'l2_cls': 0.1, 'l2_ghat': 1e-05, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 3, 'randfeat_x0_dim': 512, 'randfeat_xt_dim': 512, 'seed': 9, 'upscale_type': 'identity', 'use_batchnorm': True}]
#
# RFNN best params [{'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 0, 'upscale_type': 'SWIM'}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 1, 'upscale_type': 'SWIM'}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 2, 'upscale_type': 'SWIM'}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 3, 'upscale_type': 'SWIM'}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 4, 'upscale_type': 'SWIM'}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 5, 'upscale_type': 'SWIM'}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 6, 'upscale_type': 'SWIM'}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 7, 'upscale_type': 'SWIM'}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 8, 'upscale_type': 'SWIM'}, {'SWIM_scale': 1.0, 'activation': 'tanh', 'hidden_dim': 512, 'in_dim': 2, 'l2_cls': 0.0001, 'modelClass': <class 'models.random_feature_representation_boosting.GradientRFRBoostClassifier'>, 'n_classes': 3, 'n_layers': 0, 'seed': 9, 'upscale_type': 'SWIM'}]
#
# Logistic Regression best params [{'l2_lambda': 1.0, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 0}, {'l2_lambda': 0.01, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 1}, {'l2_lambda': 0.0001, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 2}, {'l2_lambda': 1.0, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 3}, {'l2_lambda': 0.01, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 4}, {'l2_lambda': 0.01, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 5}, {'l2_lambda': 0.1, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 6}, {'l2_lambda': 0.0001, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 7}, {'l2_lambda': 1.0, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 8}, {'l2_lambda': 0.01, 'modelClass': <class 'models.base.LogisticRegression'>, 'n_classes': 3, 'seed': 9}]
#
# End2EndMLP best params [{'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 0, 'upsample': False, 'weight_decay': 1e-05}, {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.0001, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 1, 'upsample': False, 'weight_decay': 1e-05}, {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 2, 'upsample': False, 'weight_decay': 1e-05}, {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 3, 'upsample': False, 'weight_decay': 1e-05}, {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 4, 'upsample': False, 'weight_decay': 1e-05}, {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 5, 'upsample': False, 'weight_decay': 1e-05}, {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 6, 'upsample': False, 'weight_decay': 1e-05}, {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.001, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 7, 'upsample': False, 'weight_decay': 1e-05}, {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.0001, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 8, 'upsample': False, 'weight_decay': 1e-05}, {'activation': Tanh(), 'batch_size': 64, 'bottleneck_dim': 512, 'end_lr_factor': 0.01, 'hidden_dim': 2, 'in_dim': 2, 'loss': 'cce', 'lr': 0.01, 'modelClass': <class 'models.end2end.End2EndMLPResNet'>, 'n_blocks': 3, 'n_epochs': 30, 'out_dim': 3, 'seed': 9, 'upsample': False, 'weight_decay': 1e-05}]

# %%
def create_latex_table(results):
    table = """
\\begin{table}[t]
\\caption{Average test accuracies on the concentric circles point cloud separation task, averaged across 10 runs.}
\\label{tab:concentric-circles}
\\vskip 0.15in
\\begin{center}
\\begin{small}
\\begin{sc}
\\begin{tabular}{lcc}
\\toprule
Model & Mean Acc & Std Dev \\\\
\\midrule
"""
    for model_name, accs in results.items():
        mean_acc = np.mean(accs)
        std_acc = np.std(accs)
        table += f"{model_name} & {mean_acc:.3f} & {std_acc:.3f} \\\\\n"
    
    table += """
\\bottomrule
\\end{tabular}
\\end{sc}
\\end{small}
\\end{center}
\\vskip -0.1in
\\end{table}
"""
    return table

# Example usage
latex_table = create_latex_table(results)
print(latex_table)
# Out:
# \begin{table}[t]
# \caption{Average test accuracies on the concentric circles point cloud separation task, averaged across 10 runs.}
# \label{tab:concentric-circles}
# \vskip 0.15in
# \begin{center}
# \begin{small}
# \begin{sc}
# \begin{tabular}{lcc}
# \toprule
# Model & Mean Acc & Std Dev \\
# \midrule
# RFRBoost SWIM & 0.997 & 0.002 \\
# RFNN & 0.878 & 0.027 \\
# Logistic Regression & 0.327 & 0.019 \\
# End2EndMLP & 0.488 & 0.129 \\
#
# \bottomrule
# \end{tabular}
# \end{sc}
# \end{small}
# \end{center}
# \vskip -0.1in
# \end{table}
